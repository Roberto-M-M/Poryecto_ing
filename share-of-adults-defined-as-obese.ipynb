# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Roberto-M-M/Poryecto_ing/main/share-of-adults-defined-as-obese.csv"
datos_csv = pd.read_csv(url, encoding='latin1')
datos_csv
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1975
# 1     Afghanistan  AFG  1976
# 2     Afghanistan  AFG  1977
# 3     Afghanistan  AFG  1978
# 4     Afghanistan  AFG  1979
# ...           ...  ...   ...
# 8269     Zimbabwe  ZWE  2012
# 8270     Zimbabwe  ZWE  2013
# 8271     Zimbabwe  ZWE  2014
# 8272     Zimbabwe  ZWE  2015
# 8273     Zimbabwe  ZWE  2016
#
#       Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years
# 0                                                   0.4
# 1                                                   0.4
# 2                                                   0.5
# 3                                                   0.5
# 4                                                   0.5
# ...                                                 ...
# 8269                                               11.1
# 8270                                               11.3
# ...

# %%
datos_csv.isna().sum() #datos faltantes
# Out:
# Entity                                                                                                            0
# Code                                                                                                            294
# Year                                                                                                              0
# Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years      0
# dtype: int64

# %%
datos_csv.nunique() #datos duplicados
# Out:
# Entity                                                                                                          197
# Code                                                                                                            190
# Year                                                                                                             42
# Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years    493
# dtype: int64

# %%
datos_csv[datos_csv.duplicated(subset = ['Entity','Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years'],keep=False)].sort_values('Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years')
# Out:
#                     Entity Code  Year  \
# 8064               Vietnam  VNM  1975
# 8065               Vietnam  VNM  1976
# 8066               Vietnam  VNM  1977
# 8067               Vietnam  VNM  1978
# 8070               Vietnam  VNM  1981
# ...                    ...  ...   ...
# 7802  United Arab Emirates  ARE  2007
# 6079                 Qatar  QAT  2006
# 6077                 Qatar  QAT  2004
# 6080                 Qatar  QAT  2007
# 6078                 Qatar  QAT  2005
#
#       Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years
# 8064                                                0.1
# 8065                                                0.1
# 8066                                                0.1
# 8067                                                0.1
# 8070                                                0.2
# ...                                                 ...
# ...
